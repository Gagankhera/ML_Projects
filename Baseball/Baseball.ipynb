# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# ### Input features:
# Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors

# %% [markdown]
# ### Output:
# Number of predicted wins (W).

# %% [markdown]
# # Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# This dataset contains 16 features which contains statistics summary of the Baseball players and the other feature is our target
# variable.Here, 'W' is the target variable which predicts the number of wins. We can also obsereve that this datset has only numericdata and no column has categorical data. And we can say that, it is a type of Regression Problem Statement.

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
#  Displaying first 5 rows of the dataset.

# %% [markdown]
# ## Exploratorty Data Analysis:

# %%
# Checking the dimensions of this dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset contains 30 rows and 17 columns including the target variable.

# %%
# checkng the columns present in the dataset
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the columns present in the dataset

# %%
# Cheching the datatypes of all the columns os this dataset
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# * Here, we can observe that all columns are of int datatype except ERA(Earned Run Average) column which is of float datatype.
# * Also, there is no object datatype, so no categorical data and no need to encode data.

# %%
# For getting the overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# We are getting the good overview of the dataset, which includes indexing type, column type, no-null values, data types and memory usage.

# %%
# checking the unique values of all the columns of this datatype
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# Getting the number of unique values that every column has.

# %%
# checking the null values in the dataframe
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no missing values in this dataset. It states that the baseball dataset is clear.

# %% [markdown]
# ##### Visualizing using Heatmap

# %%
# Visualizing the null values in dataframe
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# This visulization clears that no null values are present in this dataset.

# %%
# Checking the uniqueness of the target column
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# These are the unique values present in the target variable'W.

# %%
# List of values in the target variable
df['W'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %% [markdown]
# This is the list of the values of the target variable which has int datatype

# %%
# Checking whether the dataset contains any space
df.loc[df['W']==" "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# And we can see there is no space in the dataset

# %% [markdown]
# # Description of Dataset:

# %%
#Checking the Statisticalo Summary of the dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This gives the Statistical description of the datset. The summary of the dataset looks perfect since there is no negative /invalid values present.
# Fom the above observation, we can conclude that-
# * The counts of al the columns are the same. So there are no null values in the dataset.
# * The mean is bit less than the medn(50%) in the Target column, it means it is skewed to the left.
# * The mean of the target column is 80.96 and the maximum(Max) is 100, it means that the team won more matches.
# * The Runs('R') column also has the median more than the mean, it means it is also left skewed.
# * Same differences can also be seen in the columns ['2B','BB','SO','RA','ER','ERA','SHO'].So these columns are also negatively skewed.
# * But in Columns '3B' and 'SB', the mean and the median is the same,which means the data is normal or symmetrical. Also the feature
# CG has mean bit higher t6han the median so its almost normal.
# * Also there is a huge differences in max and 70% percentile(3rd quantile).
# * The above all observations clears that the outliers present in many of these columns.

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(15,5))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This is the heatmap whicch helps in visualizing the statistical summary of the dataset.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariate Analysis:

# %%
# Visualizing the Histogram of the Target Variable
sns.histplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# From the above histogram, we can state that the Target column has normalised data and there is no presence of skewness.
# The minimum wins of the team rate is 63 and maximum is 100 also mean of wins of the team rate is 80.
# The wins of the team is more between 75 to 80 and it is low in the range 70 to 75.

# %%
# Checking how the data has been distriubted in each column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above Distribution plots, it is observed that most of the columns are normally distributed and few of them has skewness.
# * The target column ['W'] is normally distributed and there is no skewness too.
# * The column 'R'(Runs) is not normal, it is skewed to the left. The run rate lies between 570-890.
# * The same differences can be seen in the columns 'BB','SO','RA','ERA'and'SHO'. Eventhough they looks normal but has skewness.
# * The column('AB') looks normally distributed and has no skewness. The value of AB mostly lies between 5300-5650.
# * The column 'H','HR','SV','E' are not normal and the they are skewed to the right.
# * The doubles rate('2B') is between 230-300 and it looks normally distributed but bit skewness is present.
# * The distribution of the data present in the columns '3B','SB','Cg', and 'ER' is normal and has no skewness.

# %% [markdown]
# ## Bivariate Analysis:

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs and Errors')
sns.scatterplot(df['R'],df['E'],hue=df['W'])
plt.xlabel('Runs')
plt.ylabel("Errors")
# Out:
# Text(0, 0.5, 'Errors')

# %% [markdown]
# The scatterplot gives the relation between the Runs and Errors with respect to Wins. There is no linear relationship between these columns.
# We can infer that there is no correlation. The runs between 650-730 with the error upto 95 has more wins. Also we can see the presence of outliers

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs and Hits')
sns.scatterplot(df['R'],df['H'],hue=df['W'])
plt.xlabel('Runs')
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# As we can infer that the there is no linearity between the columns. Also the rate of runs is high in the range 650 to 750 with the rate of hits renges 1500, which means the wins of the team is more in these ranges.

# %%
# Checking relation between two variable 
plt.figure(figsize=([10,6]))
plt.title("Comparison between AB and Hits")
sns.scatterplot(df['AB'],df['H'],hue=df['W'])
plt.xlabel('AtBats')
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# There is a weak linear relationship between the features. As the AB rates increases with the rate of Hits, then the wins of teams also increases.

# %%
# checking the realtionship between two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs Allowed and Earned Run Average')
sns.scatterplot(df['RA'],df['ERA'],hue=df['W'],palette='hls')
plt.xlabel("Runs Allowed")
plt.ylabel("Earneds Runs Average")
# Out:
# Text(0, 0.5, 'Earneds Runs Average')

# %% [markdown]
# From the above plot, it is seen that there is a strong relationship between these columns.
# As the Runs allowed increases, ERA also increases which leads to the increase in winning rates.

# %%
# checking the realtionship be3tween two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs and Wins')
sns.scatterplot(df['R'],df['W'])
plt.xlabel("Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Form this we can say, as run rate increases,rate of win also increases.

# %%
# checking the realtionship be3tween two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs Allowed and Wins')
sns.scatterplot(df['RA'],df['W'])
plt.xlabel("Runs Allowed")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Here, we can observe that there is a negative linear relationship between Runs Allowed and Wins.
# As the data falls from left to right, it means that the target column is highly corelated with 'RA' column.

# %%
# checking the realtionship be3tween two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Earned Runs and Wins')
sns.scatterplot(df['RA'],df['W'])
plt.xlabel("Earned Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Same observation with the Earned Runs too, it is also forming inverse linear realtion with the target. As the ER rate decreases, Winning rate also decreases.

# %%
 #checking the realtionship be3tween two variables
plt.figure(figsize=[10,6])
plt.title('Comparison between Earned Runs Average and Wins')
sns.scatterplot(df['ERA'],df['W'])
plt.xlabel("Earned Runs Average")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Even ERA i.e Earned Runs Average feature has negative linear relation with the label, stating this feature to be highly corelated with the label.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs and Earned Runs Average')
sns.scatterplot(df['ER'],df['ERA'],hue=df["W"],palette="husl");
plt.xlabel("Earned Runs")
plt.ylabel("Earned Runs Average")
# Out:
# Text(0, 0.5, 'Earned Runs Average')

# %% [markdown]
# As we can see there is a strong linear relationship between the features. As ER increases, ERA also increases.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Saves and Wins')
sns.regplot(df['SV'],df['W'])
plt.xlabel("Saves")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Here, we can state that there is a positive linear relationship between the feature Saves and label Wins

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between ShutOuts and Wins')
sns.regplot(df['SHO'],df['W'],color="r");
plt.xlabel("ShutOuts")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# There is no much linearity between the feature and the label. In some of the datapoints, we can see whenever shoutouts is high, there is a chance of win.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Complete Games and Wins')
sns.regplot(df['CG'],df['W']);
plt.xlabel("Complete Games")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Here also the data points are scattered and there is no much linear relationship between CG and Wins

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Triples and Wins')
sns.regplot(df['3B'],df['W'],color="g");
plt.xlabel("Triples")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The feature 3B(Triples) has a negative linear relationship with the target column

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Error and Wins')
sns.regplot(df['E'],df['W'],color="cyan");
plt.xlabel("Error")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The data is scattered and there is no linear relationship exist between these columns

# %% [markdown]
# # Multivariate Analysis

# %%
#checking the pairwise relation in the dataset
sns.pairplot(df,hue='W',palette="Paired")

# %% [markdown]
# This pairplot gives the pairwise relation between the columns which is plotted on the basis of the target variable'W'.
# WE can also observe relatiponship between all the featues and the labels.

# %% [markdown]
# # Correlation between the target variable and independent variable

# %%
# checking the correlation of features and labels
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# This gives the corelation between the dependent and independent variables

# %% [markdown]
# #### Visualization using heatmap

# %%
# Visualizing the correlation matrix
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),linewidths = 0.1,fmt='0.2f',annot=True,cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %% [markdown]
# This heatmap contains both negative as well as positive correlation.
# * The target 'W' is positively correlated with thew features 'SV', 'SHO','BB','HR','2B','R','SO'.
# * The target 'W' is highly negatively correlated with the features 'ERA','ER', and 'RA'.
# * The target 'W' is also negatively correlated with the features 'E','SB','3B' and 'AB'.
# * Apart frojm this labels and features correlations, we can also observe that the features 'ERA','ER',nad'RA' are highly positively correlated with each other which can create multicolinearity problem.

# %% [markdown]
# #### Positively Correlated Colums:

# %% [markdown]
# * SV(Saves)
# * SHO(Shoutouts)
# * BB(Walks)
# * 2B(Doubles)
# * R(Runs)
# * HR(Homeruns)
# * CG(Complete Games)
# * SO(Strikeouts)

# %% [markdown]
# #### Negatively Correlated Columns :

# %% [markdown]
# * AB(At Bats)
# * 3B(Triples)
# * SB(Stolen bases)
# * RA(Runs allowed)
# * ER(Earned Runs)
# * ERA(Earned Run Average)
# * H(Hits)
# * E(Error)

# %% [markdown]
# # Visualizing Correlation between label and features using Heatmap

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('Correlation between label and features using Bar plot',fontsize=18)
plt.show()

# %% [markdown]
# From the Visualization, we can see that the features 'H' and 'CG' has very less correlation with the target variable.So, we can drop these columns.

# %%
df.drop('H',axis=1, inplace=True)
df.drop('CG',axis = 1, inplace=True)

# %%
df.head()
# Out:
#     W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0  95  724  5575  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1  83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2  81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3  76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4  74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86

# %%
df.shape
# Out:
# (30, 15)

# %% [markdown]
# # Checking for Outliers

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=15:
        ax=plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above visualization, we can observe that the columns 'R','ERA','SHO','SV' and 'E' has outliers. So, removing the outliers using zscore and IQR techniques before building the model.

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# ### Zscore technique:

# %%
features = df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
z
# Out:
# array([[0.61907797, 0.50695519, 0.81462859, 1.67160651, 0.46146963],
#        [0.13443166, 0.25459752, 0.1728    , 0.24987932, 0.60719689],
#        [0.33290586, 0.64134684, 0.32091429, 0.65485616, 1.11724227],
#        [1.14641931, 0.05301004, 0.56777144, 0.78410408, 0.48575751],
#        [0.01327008, 1.53131824, 0.1728    , 1.04259994, 0.60719689],
#        [3.50964704, 0.35016492, 0.32091429, 1.17184786, 0.46146963],
#        [1.31142984, 0.16500309, 1.80205719, 0.6376231 , 0.0971515 ],
#        [0.4286812 , 0.20980031, 0.32091429, 0.00861653, 1.26296953],
#        [0.76562578, 0.48455658, 0.1728    , 2.18859821, 0.04857575],
#        [1.03448909, 0.79216414, 0.32091429, 0.39636031, 0.194303  ],
#        [1.08641548, 0.63537388, 0.56777144, 0.24987932, 1.79730279],
#        [0.70562195, 0.86533293, 0.41965715, 0.52560823, 0.68006051],
#        [0.47137623, 0.03658439, 0.1728    , 0.37912725, 0.0971515 ],
#        [0.55792022, 0.45618501, 0.1728    , 0.24987932, 0.02428788],
# ...

# %%
# creating new dataframe
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#       W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0    95  724  5575  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1    83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2    81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3    76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4    74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86
# 6    87  764  5567  272  19  212  554  1227   63  698  652  4.03    4  48   93
# 7    81  713  5485  246  20  217  418  1331   44  693  646  4.05   10  43   77
# 8    80  644  5485  278  32  167  436  1310   87  642  604  3.74   12  60   95
# 9    78  748  5640  294  33  161  478  1148   71  753  694  4.31   10  40   97
# 10   88  751  5511  279  32  172  503  1233  101  733  680  4.24    9  45  119
# 11   86  729  5459  278  26  230  486  1392  121  618  572  3.57   13  39   85
# ...

# %% [markdown]
# This is the new dataframe after removing outliers.

# %%
print(df.shape)
print(new_df.shape)
# Out:
# (30, 15)
# (29, 15)

# %% [markdown]
# #### Data loss percent

# %%
# checking data loss prercent
data_loss = (30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# So, using zscore the data loss is not more.
# Now checking with IQR technique.

# %% [markdown]
# # IQR(Inter Quantile Range) method

# %%
# 1st quantile
Q1 = features.quantile(0.25)

# 3rd Quantile
Q3 = features.quantile(0.75)

#IQR
IQR = Q3-Q1

df1 = df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]

# %%
print(df.shape)
print(df1.shape)
# Out:
# (30, 15)
# (20, 15)

# %%
# checking data loss
loss = (30-20)/30*100
loss
# Out:
# 33.33333333333333

# %% [markdown]
# There is a huge data loss using IQR, so we will consider Zscore method.

# %% [markdown]
# # Checking for Skewness

# %%
#checking the skewness
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# The skewness is present in the columns 'SHO','SV' and'E'.

# %% [markdown]
# # Removing skewness using yeo-johnson method

# %%
skewed_features = ['SHO','SV','E']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
new_df[skewed_features] = scaler.fit_transform(new_df[skewed_features].values)
new_df[skewed_features].head()
# Out:
#         SHO        SV         E
# 0 -0.787002  1.532753 -0.348265
# 1  0.236737  0.312020 -0.540820
# 2 -0.252844 -0.664137 -1.326125
# 3 -0.513555 -0.820689  0.650818
# 4  0.236737 -1.149165 -0.540820

# %%
# Checking the skewness after applying yeo-johnson method.
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# We can see that the skewness has been removed. Now, lets visualize it by using distplot.

# %%
# After removing skewness,visualizing the dta distribution in each column.# Checking how the data has been distriubted in each column
features_skewed = ['SHO','SV','E']
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Now the data is normally distributed and the skewness is also removed.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Sparating dependent and independent variables

# %%
x = new_df.drop('W', axis=1)
y = new_df['W']

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.752672  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.412514 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# ...

# %% [markdown]
# This is the scaled data using standard scaler.

# %% [markdown]
# # Check for Multicolinearity:

# %%
# checking VIF (Variance Inflation factor)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#      VIF values Features
# 0      6.219825        R
# 1      9.828077       AB
# 2      2.683572       2B
# 3      3.196853       3B
# 4      7.369072       HR
# 5      2.686472       BB
# 6      2.741072       SO
# 7      1.757901       SB
# 8    179.096825       RA
# 9   1754.643859       ER
# 10  1310.260128      ERA
# 11     3.086344      SHO
# 12     4.021573       SV
# 13     1.742105        E

# %% [markdown]
# The VIF value is more than 10 in the columns 'AB','RA','ER','ERA'.We can drop highest VIF value that is 'ER'.

# %%
x.drop('ER', axis =1, inplace=True)

# %%
# Again checking the VIF after removing one column
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values Features
# 0     4.352902        R
# 1     3.177214       AB
# 2     2.597985       2B
# 3     3.072775       3B
# 4     4.949255       HR
# 5     2.561982       BB
# 6     2.661842       SO
# 7     1.680467       SB
# 8   119.939744       RA
# 9   111.859162      ERA
# 10    2.932319      SHO
# 11    2.112465       SV
# 12    1.742101        E

# %% [markdown]
# we can observe that multicolinearity still exists, so we can drop column 'RA' as it has high vif value.

# %%
x.drop('RA',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     4.250076        R
# 1     2.238746       AB
# 2     2.597917       2B
# 3     3.030073       3B
# 4     4.562014       HR
# 5     2.222720       BB
# 6     2.042786       SO
# 7     1.568151       SB
# 8     3.878177      ERA
# 9     2.651314      SHO
# 10    1.954370       SV
# 11    1.493128        E

# %% [markdown]
# Now, we can observe that VIF values of all columns are less than 10. Multicolinearity problem is solved.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Finding the best random state

# %%
from sklearn.model_selection import train_test_split as TTS
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
maxAcc = 0
maxRS = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.30,random_state=i)
    model = LinearRegression()
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print("Maximum r2 score is ",maxAcc,"at random state ",maxRS)
# Out:
# Maximum r2 score is  0.9291790579976077 at random state  50

# %% [markdown]
# Getting maximum R2 scoreas 92% at random state 50

# %%
x_train,x_test,y_train,y_test = TTS(x,y,test_size=0.30,random_state=maxRS)

# %% [markdown]
# # Regression Algorithms

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %% [markdown]
# # Linear Regression

# %%
#checking r2 score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predLR))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predLR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predLR)))
# Out:
# R2_score: 0.9291790579976077
# MAE: 2.4627865987898425
# MSE: 10.163242343651953
# RMSE: 3.1879840563672763

# %% [markdown]
# The r2_score value of Linbear Regression model is 92.91%.

# %% [markdown]
# # Ridge Regressor

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01,0.1,1.0,10.26],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
ridge = Ridge()
clf = GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'sag'}

# %%
#checking r2 score for Ridge
ridge = Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge = ridge.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_ridge))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_ridge))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_ridge))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_score: 0.8226588457310873
# MAE: 4.389357547750923
# MSE: 25.449550336072125
# RMSE: 5.044754734976927

# %% [markdown]
# The r2_score of Ridge Regressor is 82%

# %% [markdown]
# # Lasso Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso = Lasso()
clf = GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
#checking r2 score for Lasso
lasso = Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso = lasso.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_lasso))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_lasso))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_lasso))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.8642951302468397
# MAE: 3.8253497504300973
# MSE: 19.4744864939597
# RMSE: 4.41299065192299

# %% [markdown]
# The R2_score using Lasso Regressor is 86%.

# %% [markdown]
# # Stochastic Gradient Descent Regressor

# %%
#checking r2 score for Stochastic Gradient Descent Regressor
SGD = SGDRegressor()
SGD.fit(x_train,y_train)

predSGD=SGD.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predSGD))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predSGD))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predSGD))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predSGD)))
# Out:
# R2_score: 0.9305281281340076
# MAE: 2.7292448037619312
# MSE: 9.969642451485118
# RMSE: 3.1574740618863553

# %% [markdown]
# The R2_score using SGDRegressor is 93%.

# %% [markdown]
# # Checking for Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking CV score for LinearRegression
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.3734441230489941

# %%
# Checking CV score for Ridge Regression
print(cross_val_score(ridge,x,y,cv=5).mean())
# Out:
# 0.3493731526975086

# %%
# Checking CV score for Lasso Regression
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.520653701943612

# %%
# Checking CV score for SGD Regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.26583708758876956

# %% [markdown]
# From the difference of both R2_score and cross validation score, we can conclude that Lasso best fits the model.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regresssor
parameters = {'alpha':[0.01,0.1,1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV = GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 0.1,
#  'fit_intercept': 'bool',
#  'max_iter': 10,
#  'selection': 'random',
#  'tol': 1000}

# %%
# Creating Final Model
Baseball = Lasso(alpha=0.1,fit_intercept='bool',max_iter=10,selection='random',tol=1000)
Baseball.fit(x_train,y_train)
pred = Baseball.predict(x_test)
print('R2_score:',r2_score(y_test,pred_lasso)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 86.42951302468397
# RMSE value: 4.41299065192299

# %% [markdown]
# After tuning the model, the R2_score is 86.42% for the best model.

# %% [markdown]
# # Saving the model

# %%
#saving the model 
import joblib
joblib.dump(Baseball,'Baseball.pkl')
# Out:
# ['Baseball.pkl']

# %%
loadmodel = joblib.load('Baseball.pkl')

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(loadmodel.predict(x_test))
df_final = pd.DataFrame({"Original":a,"Predicted":predicted},index=range(len(a)))
df_final
# Out:
#    Original  Predicted
# 0        68  69.983725
# 1        78  80.632237
# 2        74  74.919037
# 3        88  81.828591
# 4        68  75.486245
# 5        64  71.755746
# 6        92  87.826407
# 7        90  94.916967
# 8       100  96.826290

# %% [markdown]
# This is the dataframe having original data with the predicted data from the best model.

# %% [markdown]
# # Prediction Visualization

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test,predicted,c='r')
plt1 = max(max(predicted),max(y_test))
plt2 = min(min(predicted),min(y_test))
plt.plot([plt1,plt2],[plt1,plt2],'b-')
plt.xlabel('Actual Win',fontsize=15)
plt.ylabel('Predicted Win',fontsize=15)
plt.title("Lasso Regressor")
plt.show()

# %% [markdown]
# Here the blue line represents the actual win and red dots are the predicted win.
